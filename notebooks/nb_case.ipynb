# %% [markdown]
# # Palmer Penguins: Exploratory Data Analysis (EDA)
#
# **Author:** Your Name
# **Created:** YYYY-MM
# **Course:** Data Analytics Fundamentals (P04)
# **Notebook purpose:** Explore a real dataset and practice a standard EDA workflow in a notebook.

# %% [markdown]
# ## 1. Data Source and Provenance
#
# **Dataset name:** Palmer Penguins (Palmer Archipelago, Antarctica) :contentReference[oaicite:0]{index=0}
#
# **Who created / curated it (how to credit):**
# Horst, Hill, and Gorman (2020), distributed as the `palmerpenguins` dataset. :contentReference[oaicite:1]{index=1}
#
# **License / usage:**
# Data are available under CC0. :contentReference[oaicite:2]{index=2}
#
# **Where I got it:**
# - Source link (or package): __________________________
# - Date accessed: __________________________
#
# **Where it is stored in this project:**
# - `data/raw/`: __________________________ (file name)
#
# **What one row represents:**
# One penguin observation with measurements (e.g., bill length, flipper length) and identifiers (species, island, etc.). :contentReference[oaicite:3]{index=3}

# %% [markdown]
# ## 2. Dataset Size and Structure
#
# After loading the dataset, record:
#
# - **Number of records (rows):** ______
# - **Number of columns (fields):** ______
#
# **Column inventory (quick list):**
# Paste the column names here after loading.

# %% [markdown]
# ## 3. Data Dictionary
#
# A **data dictionary** explains what each column means, including units and allowed values.
#
# For this notebook:
# - We may summarize key columns in Markdown
# - A full data dictionary can also live in a separate file (common professional practice)
# - You will be required to produce a formal data dictionary later (capstone)
#
# **Data dictionary location (choose one):**
# - In this notebook (brief summary), OR
# - Separate file (recommended later): `docs/data_dictionary.md`, OR
# - External official source: __________________________

# %%
## 4. Guiding Question (EDA Goal)

**Exploration question:**  
Can we use penguin measurements (such as bill length, bill depth, flipper length, body mass) to distinguish species?

This is not a final model.
The goal is to explore patterns and develop intuition.

# %% [markdown]
# ## 5. Imports and Configuration
#
# Notes:
# - Notebooks use **Markdown cells** for explanations and **code cells** for Python.
# - Run cells in order for reproducible results.
# - This cell is Markdown.
# - The next cell is Code.

# %% [markdown]
# from pathlib import Path
#
# import pandas as pd

# %%
## 6. Load the Data

After loading:
- show the first few rows
- verify the dataset size (rows, columns)

- This cell is Markdown.
- The next cell is Code.

# %%
# Read CSV into a DataFrame
df = pd.read_csv(RAW_PATH)

print("Loaded data from:", RAW_PATH)
print("Rows, Columns:", df.shape)

# %% [markdown]
# ## 7. Initial Inspection
#
# - This cell is Markdown.
# - The next cell is Code.
#
# Suggested checks:
# - first 5 rows
# - column names
# - data types
# - basic summary
#
# Write 2-3 sentences here describing what you notice at first glance.

# %%
print("\nFirst 5 rows:")
print(df.head())

print("\nColumn names:")
print(list(df.columns))

print("\nInfo (types, non-null counts):")
print(df.info())
